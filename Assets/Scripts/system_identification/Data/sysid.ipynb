# %%
using StaticArrays, SeeToDee

function asv(v, input, p, t)
    m1, m2, m3 = p[1], p[2], p[3]
    Xu, Yv, Yr, Nv, Nr = p[4], p[5], p[6], p[7], p[8]
    Xuu, Yvv, Nrr = p[9], p[10], p[11]
    Xuuu, Yvvv, Nrrr = p[12], p[13], p[14]
    
    u, v, r = v[1], v[2], v[3]
    X, Y, N = input[1], input[2], input[3]

    v1 = (1/m1) * (Xu*u + Xuu*abs(u)*u + Xuuu*u^3 + X)
    v2 = (1/m2) * (Yv*v + Yr*r + Yvv*abs(v)*v + Yvvv*v^3 + Y)
    v3 = (1/m3) * (Nv*v + Nr*r + Nrr*abs(r)*r + Nrrr*r^3 + N)

    return SA[v1, v2, v3]
end


measurement(v, u, p, t) = SA[v[1], v[2], v[3]]
Ts = 0.02
discrete_dynamics = SeeToDee.Rk4(asv, Ts, supersample=2)
# Out:
# SeeToDee.Rk4{typeof(asv), Float64}(asv, 0.02, 2)

# %%
using CSV
using DataFrames
using Plots

# Read the CSV data into a DataFrame
df = CSV.File("data.csv", header=false) |> DataFrame
t = df[:, 1]
# position and orientation
x = df[:, 2]
y = df[:, 3]
psi = df[:, 4]

# velocities (states)
u = df[:, 5]
v = df[:, 6]
r = df[:, 7]

# forces and moments (inputs)
Fx = df[:, 8]
Fy = df[:, 9]
Nz = df[:, 10]

nx = 3
ny = 3
nu = 3
# Out:
# 3

# %%
using Plots

plt = plot(layout = (6,1), size=(600,800))

plot!(plt[1], t, x, label="Position X (East)", legend=:topright)
plot!(plt[1], t, y, label="Position Y (North)", legend=:topright, xlabel="Time [s]", ylabel="Position [m]", title="Position Over Time")

plot!(plt[2], t, psi, label="Yaw Angle (psi)", color=:orange, legend=:topright, xlabel="Time [s]", ylabel="Yaw Angle [degrees]", title="Yaw Angle Over Time")

plot!(plt[3], t, u, label="Velocity U (Vz)", color=:green, legend=:topright, xlabel="Time [s]", ylabel="Velocity [m/s]", title="Velocities Over Time")
plot!(plt[3], t, v, label="Velocity V (Vx)", color=:red, legend=:topright)

plot!(plt[4], t, r, label="Angular Velocity R (Wy)", color=:purple, legend=:topright, xlabel="Time [s]", ylabel="Angular Velocity [rad/s]", title="Angular Velocity Over Time")

plot!(plt[5], t, Fx, label="Force X (Fx)", color=:cyan, legend=:topright, xlabel="Time [s]", ylabel="Force [N] / Torque [Nm]", title="Forces and Torque Over Time")
plot!(plt[5], t, Fy, label="Force Y (Fy)", color=:magenta, legend=:topright)
plot!(plt[5], t, Nz, label="Torque (T)", color=:blue, legend=:topright)

plot!(plt[6], x, y, label="position", color=:cyan, xlabel="X [m]", ylabel="Y [m]", title="xy position")
plot!(plt[6], yflip=true)

display(plt)

# %%
using ControlSystemIdentification, ControlSystemsBase
using ControlSystemsBase.DemoSystems: resonant
using LowLevelParticleFilters
using LeastSquaresOptim
using Random, Plots, LinearAlgebra

# Create input and output matrices
U = vcat.(Fx, Fy, Nz)
Y = vcat.(u, v, r) 

U = reduce(hcat, U)
Y = reduce(hcat, Y)

d = iddata(Y, U, Ts)
x0_guess = [0.1, 0.1, 0.1] # Guess for the initial condition
p_guess = zeros(14)

R1 = Diagonal([0.1, 0.1, 0.1])
R2 = Diagonal([0.1, 0.1, 0.1])

model = ControlSystemIdentification.nonlinear_pem(d, discrete_dynamics, measurement, p_guess, x0_guess, R1, R2, nu)
# Out:
# PosDefException: matrix is not Hermitian; Cholesky factorization failed.
#
#
#
# Stacktrace:
#
#   [1] non_hermitian_error()
#
#     @ StaticArrays C:\Users\edvar\.julia\packages\StaticArrays\cZ1ET\src\cholesky.jl:2
#
#   [2] #cholesky#532
#
#     @ C:\Users\edvar\.julia\packages\StaticArrays\cZ1ET\src\cholesky.jl:4 [inlined]
#
#   [3] cholesky
#
#     @ C:\Users\edvar\.julia\packages\StaticArrays\cZ1ET\src\cholesky.jl:3 [inlined]
#
#   [4] correct!(ukf::UnscentedKalmanFilter{SeeToDee.Rk4{typeof(asv), Float64}, typeof(measurement), SMatrix{3, 3, Float64, 9}, SMatrix{3, 3, Float64, 9}, Distributions.MvNormal{Float64, PDMats.PDMat{Float64, Matrix{Float64}}, SVector{3, Float64}}, SVector{3, Float64}, Vector{Float64}, Matrix{Float64}, Vector{Float64}}, u::SVector{3, Float64}, y::SVector{3, Float64}, p::Vector{Float64}, t::Int64; R2::SMatrix{3, 3, Float64, 9})
#
#     @ LowLevelParticleFilters C:\Users\edvar\.julia\packages\LowLevelParticleFilters\rO2as\src\ukf.jl:111
#
#   [5] correct!
#
#     @ C:\Users\edvar\.julia\packages\LowLevelParticleFilters\rO2as\src\ukf.jl:93 [inlined]
#
#   [6] update!
#
#     @ C:\Users\edvar\.julia\packages\LowLevelParticleFilters\rO2as\src\filtering.jl:133 [inlined]
#
#   [7] AbstractUnscentedKalmanFilter (repeats 2 times)
#
#     @ C:\Users\edvar\.julia\packages\LowLevelParticleFilters\rO2as\src\filtering.jl:182 [inlined]
#
#   [8] prediction_errors!(res::Vector{Float64}, f::UnscentedKalmanFilter{SeeToDee.Rk4{typeof(asv), Float64}, typeof(measurement), SMatrix{3, 3, Float64, 9}, SMatrix{3, 3, Float64, 9}, Distributions.MvNormal{Float64, PDMats.PDMat{Float64, Matrix{Float64}}, SVector{3, Float64}}, SVector{3, Float64}, Vector{Float64}, Matrix{Float64}, Vector{Float64}}, u::Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, y::Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, p::Vector{Float64}, λ::Float64)
#
#     @ LowLevelParticleFilters C:\Users\edvar\.julia\packages\LowLevelParticleFilters\rO2as\src\smoothing.jl:104
#
#   [9] (::ControlSystemIdentificationLSOptExt.var"#residuals!#5"{Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, Vector{Float64}, Float64, ControlSystemIdentificationLSOptExt.var"#get_ukf#4"{SVector{3, Int64}, SeeToDee.Rk4{typeof(asv), Float64}, typeof(measurement), Vector{Float64}, Int64, SMatrix{3, 3, Float64, 9}, SMatrix{3, 3, Float64, 9}, Bool, Matrix{Float64}}})(ϵ::Vector{Float64}, px0::Vector{Float64})
#
#     @ ControlSystemIdentificationLSOptExt C:\Users\edvar\.julia\packages\ControlSystemIdentification\KMsrd\ext\ControlSystemIdentificationLSOptExt.jl:124
#
#  [10] optimize!(anls::LeastSquaresProblemAllocated{Vector{Float64}, Vector{Float64}, ControlSystemIdentificationLSOptExt.var"#residuals!#5"{Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, Vector{Float64}, Float64, ControlSystemIdentificationLSOptExt.var"#get_ukf#4"{SVector{3, Int64}, SeeToDee.Rk4{typeof(asv), Float64}, typeof(measurement), Vector{Float64}, Int64, SMatrix{3, 3, Float64, 9}, SMatrix{3, 3, Float64, 9}, Bool, Matrix{Float64}}}, Matrix{Float64}, LeastSquaresOptim.var"#4#6"{ControlSystemIdentificationLSOptExt.var"#residuals!#5"{Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, Vector{Float64}, Float64, ControlSystemIdentificationLSOptExt.var"#get_ukf#4"{SVector{3, Int64}, SeeToDee.Rk4{typeof(asv), Float64}, typeof(measurement), Vector{Float64}, Int64, SMatrix{3, 3, Float64, 9}, SMatrix{3, 3, Float64, 9}, Bool, Matrix{Float64}}}, ForwardDiff.JacobianConfig{ForwardDiff.Tag{ControlSystemIdentificationLSOptExt.var"#residuals!#5"{Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, Vector{Float64}, Float64, ControlSystemIdentificationLSOptExt.var"#get_ukf#4"{SVector{3, Int64}, SeeToDee.Rk4{typeof(asv), Float64}, typeof(measurement), Vector{Float64}, Int64, SMatrix{3, 3, Float64, 9}, SMatrix{3, 3, Float64, 9}, Bool, Matrix{Float64}}}, Float64}, Float64, 9, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{ControlSystemIdentificationLSOptExt.var"#residuals!#5"{Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, Vector{Float64}, Float64, ControlSystemIdentificationLSOptExt.var"#get_ukf#4"{SVector{3, Int64}, SeeToDee.Rk4{typeof(asv), Float64}, typeof(measurement), Vector{Float64}, Int64, SMatrix{3, 3, Float64, 9}, SMatrix{3, 3, Float64, 9}, Bool, Matrix{Float64}}}, Float64}, Float64, 9}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{ControlSystemIdentificationLSOptExt.var"#residuals!#5"{Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, Vector{Float64}, Float64, ControlSystemIdentificationLSOptExt.var"#get_ukf#4"{SVector{3, Int64}, SeeToDee.Rk4{typeof(asv), Float64}, typeof(measurement), Vector{Float64}, Int64, SMatrix{3, 3, Float64, 9}, SMatrix{3, 3, Float64, 9}, Bool, Matrix{Float64}}}, Float64}, Float64, 9}}}}}, LeastSquaresOptim.AllocatedLevenbergMarquardt{Vector{Float64}, Vector{Float64}, Vector{Float64}, Vector{Float64}}, LeastSquaresOptim.DenseQRAllocatedSolver{Matrix{Float64}, Vector{Float64}}}; x_tol::Float64, f_tol::Float64, g_tol::Float64, iterations::Int64, Δ::Float64, store_trace::Bool, show_trace::Bool, show_every::Int64, lower::Vector{Float64}, upper::Vector{Float64})
#
#     @ LeastSquaresOptim C:\Users\edvar\.julia\packages\LeastSquaresOptim\GDeuc\src\optimizer\levenberg_marquardt.jl:63
#
#  [11] optimize!
#
#     @ C:\Users\edvar\.julia\packages\LeastSquaresOptim\GDeuc\src\optimizer\levenberg_marquardt.jl:44 [inlined]
#
#  [12] #optimize!#11
#
#     @ C:\Users\edvar\.julia\packages\LeastSquaresOptim\GDeuc\src\types.jl:149 [inlined]
#
#  [13] _inner_pem(Ts::Float64, yvv::Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, uvv::Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, x0inds::SVector{3, Int64}, discrete_dynamics::SeeToDee.Rk4{typeof(asv), Float64}, measurement::typeof(measurement), p0::Vector{Float64}, x0::SVector{3, Float64}, nu::Int64, R1::SMatrix{3, 3, Float64, 9}, R2::SMatrix{3, 3, Float64, 9}, optimizer::LevenbergMarquardt{Nothing}, λ::Float64, optimize_x0::Bool; kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ ControlSystemIdentificationLSOptExt C:\Users\edvar\.julia\packages\ControlSystemIdentification\KMsrd\ext\ControlSystemIdentificationLSOptExt.jl:135
#
#  [14] _inner_pem(Ts::Float64, yvv::Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, uvv::Base.ReinterpretArray{SVector{3, Float64}, 2, Float64, Matrix{Float64}, false}, x0inds::SVector{3, Int64}, discrete_dynamics::SeeToDee.Rk4{typeof(asv), Float64}, measurement::typeof(measurement), p0::Vector{Float64}, x0::SVector{3, Float64}, nu::Int64, R1::SMatrix{3, 3, Float64, 9}, R2::SMatrix{3, 3, Float64, 9}, optimizer::LevenbergMarquardt{Nothing}, λ::Float64, optimize_x0::Bool)
#
#     @ ControlSystemIdentificationLSOptExt C:\Users\edvar\.julia\packages\ControlSystemIdentification\KMsrd\ext\ControlSystemIdentificationLSOptExt.jl:96
#
#  [15] nonlinear_pem(d::InputOutputData{Matrix{Float64}, Matrix{Float64}, Float64}, discrete_dynamics::SeeToDee.Rk4{typeof(asv), Float64}, measurement::Function, p0::Vector{Float64}, x0::Vector{Float64}, R1::Diagonal{Float64, Vector{Float64}}, R2::Diagonal{Float64, Vector{Float64}}, nu::Int64; optimizer::LevenbergMarquardt{Nothing}, λ::Float64, optimize_x0::Bool, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ ControlSystemIdentificationLSOptExt C:\Users\edvar\.julia\packages\ControlSystemIdentification\KMsrd\ext\ControlSystemIdentificationLSOptExt.jl:82
#
#  [16] nonlinear_pem(d::InputOutputData{Matrix{Float64}, Matrix{Float64}, Float64}, discrete_dynamics::SeeToDee.Rk4{typeof(asv), Float64}, measurement::Function, p0::Vector{Float64}, x0::Vector{Float64}, R1::Diagonal{Float64, Vector{Float64}}, R2::Diagonal{Float64, Vector{Float64}}, nu::Int64)
#
#     @ ControlSystemIdentificationLSOptExt C:\Users\edvar\.julia\packages\ControlSystemIdentification\KMsrd\ext\ControlSystemIdentificationLSOptExt.jl:46
#
#  [17] top-level scope
#
#     @ c:\Users\edvar\ASV\Assets\Scripts\sysid\Data\sysid.ipynb:21
